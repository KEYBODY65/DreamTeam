# %% [markdown]
# <a href="https://colab.research.google.com/github/KEYBODY65/DreamTeam/blob/main/cu_stat_hw02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Задача 1. Представь описательные статистики в сводной таблице

# %% [markdown]
# Датасет [golden_mine.csv](https://raw.githubusercontent.com/zalig/cu-datasets/main/golden_mine.csv) содержит данные для кейса [«Золотая жила»](https://raw.githubusercontent.com/zalig/cu-datasets/main/case_1_golden_mine.pdf), в котором нужно с помощью датасета найти наиболее прибыльные категории клиентов — пользователей
# платформы для изучения иностранного языка.
#
# Это задание позволяет познакомиться с датасетом и провести в нём некоторые расчёты. Целиком решать кейс пока не требуется.
#
# Описание столбцов датасета:
#
# - Gender – пол клиента;
# - Age — возраст клиента в годах;
# - Age Group — возрастная группа;
# - Payments — общая сумма платежей от клиента в рублях за всё время существования платформы;
# - Costs — себестоимость оказанных клиенту услуг в рублях за всё время существования платформы;
# - Profit — разница между Payments и Costs.

# %%
import pandas as pd
df=pd.read_csv('https://raw.githubusercontent.com/zalig/cu-datasets/main/golden_mine.csv')
df.head(2)
# Out:
#    Payments  Costs  Profit  Age Gender AgeGroup
# 0      9400   8100    1300   19   male    18-24
# 1     26600  13900   12700   29   male    25-39

# %% [markdown]
# ##1. (blue, баллы: 0.4) Без предварительной очистки данных построй сводную таблицу:
#   - в строках — пол клиента Gender;
#   - в столбцах — возрастная категория Age Group;
#   - в ячейках — количество клиентов выбранного пола в выбранной возрастной категории.
#
#   Сделай выводы: какая нужна очистка данных.

# %% [markdown]
# **Решение**

# %%
# Решение

# %% [markdown]
# ##2. (blue, баллы: 0.8) Очисти данные и пересчитай таблицу из предыдущего пункта.

# %% [markdown]
# **Решение**

# %% [markdown]
# ##3. (blue, баллы: 1.2) Без предварительной очистки данных построй сводную таблицу:
#   - в строках — пол клиента Gender;
#   - в столбцах — возрастная категория Age Group;
#   - в ячейках — средняя прибыль среди клиентов выбранного пола в выбранной возрастной категории.
#
#   Сделай выводы о необходимости дальнейшей очистки данных.

# %% [markdown]
# **Решение**

# %% [markdown]
# ##4. (red, баллы: 0.4) Очисти данные и пересчитай таблицу.

# %% [markdown]
# **Решение**

# %% [markdown]
# ##5. (red, баллы: 0.4) Без предварительной очистки данных построй сводную таблицу:
#   - в строках — пол клиента Gender;
#   - в столбцах — возрастная категория Age Group;
#   - в ячейках — доля клиентов с прибылью больше 60 тысяч рублей среди клиентов выбранного пола в выбранной возрастной категории.

# %% [markdown]
# **Решение**

# %% [markdown]
# # Задача 2. Построй столбчатую диаграмму barchart

# %% [markdown]
# Описание датасета [golden_mine.csv](https://https://raw.githubusercontent.com/zalig/cu-datasets/main/golden_mine.csv) есть в предыдущей задаче.

# %% [markdown]
# Построй графики.
#
# Главное требование к каждому графику — он должен быть читаемым и понятным «сам по себе», без окружающего текста.
#
# Можно представлять, что кто-то сделает скриншот графика и разместит на чистом листе. Нужно, чтобы график и после этого оставался понятным.
#
# Поэтому у графика есть обязательные элементы:
#   - длинный заголовок, полностью объясняющий, какие данные представлены на графике;
#   - смысловые подписи осей, единицы измерения;
#   - легенда для каждого цвета, если использованы разные цвета.
#
# Подсказка: можно предварительно очистить данные.

# %% [markdown]
# ## 1. (blue, баллы: 1.6) Построй столбчатую диаграмму (англ. barchart), которая показывает частоты возрастных групп.

# %% [markdown]
# **Решение**

# %%
# Решение

# %% [markdown]
# ## 2. (red, баллы: 0.4) Построй barchart, показывающий частоты возрастных групп среди всех, среди мужчин и среди женщин.

# %% [markdown]
# **Решение**

# %%
# Решение

# %% [markdown]
# # Задача 3. Проинтерпретируй графики «из интернета»

# %% [markdown]
# Какие выводы можно сделать из каждой диаграммы ниже? Простых интерпретаций будет достаточно, но содержательные выводы ценятся выше.

# %% [markdown]
# ## 1. (blue, баллы: 1.2) Ответь на вопросы, опираясь на график.
#
# ![Столбчатая диаграмма .png](data:image/png;base64,...)

# %% [markdown]
#
#
#   Источник: https://fin-plan.org/blog/investitsii/portfel-uorrena-baffeta-itogi-2022-goda/

# %% [markdown]
# * Доля какой индустрии в инвестиционном портфеле Уоррена Баффета больше всего снизилась за 2022 год?
#
# * Доля какой индустрии в инвестиционном портфеле Уоррена Баффета больше всего увеличилась за 2022 год?
#
# * Назови индустрии, в которые Уоррен Баффет в основном инвестирует. Составь их рейтинг, исходя из процента, который они занимают в портфеле.

# %% [markdown]
# **Решение**

# %% [markdown]
# **{Своё решение напиши здесь}**

# %% [markdown]
# ## 2. (blue, баллы: 1.2) Ответь на вопросы, опираясь на график.
#
#  ![Круговая диаграмма .png](data:image/png;base64,...)

# %% [markdown]
# Источник: https://fin-plan.org/blog/investitsii/portfel-uorrena-baffeta-itogi-2022-goda/

# %% [markdown]
# * Как изменилась доля Bank of America в инвестиционном портфеле Уоррена Баффета в 2022 году?
#
# * Доля какой компании в инвестиционном портфеле Уоррена Баффета показала самое большое падение? На сколько она снизилась?
#
# * Доля какой компании в инвестиционном портфеле Уоррена Баффета показала самый большой рост? На сколько она выросла?
#
# * Какие компании исчезли из портфеля Уоррена Баффета в 2022 году?
#
# * Какие выводы на основе диаграммы можно сделать об изменениях в портфеле в 2022 году?

# %% [markdown]
# **Решение**

# %% [markdown]
# **{Своё решение напиши здесь}**

# %% [markdown]
# ## 3. (red, баллы: 0.5) Ответь на вопросы, опираясь на график.

# %% [markdown]
# ![Линейный график.png](data:image/png;base64,...)

# %% [markdown]
# Источник: https://ru.tradingview.com/chart/?symbol=NASDAQ%3AAAPL

# %% [markdown]
# * Какова была стоимость акции Apple 31.12.2021?
#
# * Какова была стоимость акции Apple 31.12.2022?
#
# * Как изменилась стоимость акции Apple с 31.12.2021 по 30.12.2022?
#
# * Какой тренд можно увидеть на графике, начиная с середины августа, заканчивая концом 2022 года?
#
#   Тренд — общее направление движения цены определённого финансового инструмента на рынке. В данном случае речь об акциях компании Apple. Тренд бывает нисходящий и восходящий.

# %% [markdown]
# **Решение**

# %% [markdown]
# **{Своё решение напиши здесь}**

# %% [markdown]
# # Задача 4. Мини-кейс «Я руководитель, получил слайды от подчинённого»

# %% [markdown]
# ## (blue, баллы: 2) Описание задачи — [в презентации](https://raw.githubusercontent.com/zalig/cu-datasets/main/case_0_hw_2.pdf).
#
# Ниже поставь оценку по критериям из презентации и напиши комментарии — обоснования своей оценки.

# %% [markdown]
# Оценка слайдов Андрея:
#
# Понятность, внешний вид — **{Заполни здесь}** из 5 баллов.
#
# Обоснованность — **{Заполни здесь}** из 5 баллов.
#
# Твоя реакция как заказчика/руководителя — **{Заполни здесь}** из 2 баллов.

# %% [markdown]
# Комментарий к оценке слайдов Андрея:
#
# **{Заполни здесь}**

# %% [markdown]
# Оценка слайдов Бориса:
#
# Понятность, внешний вид — **{Заполни здесь}** из 5 баллов.
#
# Обоснованность — **{Заполни здесь}** из 5 баллов.
#
# Твоя реакция как заказчика/руководителя — **{Заполни здесь}** из 2 баллов.

# %% [markdown]
# Комментарий к оценке слайдов Бориса:
#
# **{Заполни здесь}**

# %% [markdown]
# #Задача 5. Сделай слайд с диаграммой

# %% [markdown]
# Вернёмся к нашему кейсу. Сделай часть слайдов для кейса [«Золотая жила»](https://raw.github.com/zalig/cu-datasets/main/case_1_golden_mine.pdf) в формате pptx. Например, в PowerPoint.
#
# 1. (blue, баллы: 1.6) Слайд должен отвечать на вопрос: в какой из двух категорий клиентов «Мужчины 18-24 лет» и «Женщины 18-24 лет» выгоднее привлекать новых клиентов при одинаковой стоимости привлечения клиента.
#
#   На слайде должны быть:
#
#   - barchart, показывающий среднюю прибыль в каждой категории;
#   - barchart, показывающий долю клиентов в данной категории, прибыль с которых 60 тысяч рублей или больше;
#   - соответствующие сводные таблицы (по желанию);
#   - вывод — клиентов какой категории привлекать выгоднее.
#
# 2. (red, баллы: 0.6) Теперь от двух категорий клиентов нужно перейти ко всем возможным — по полу и возрастной группе. Необходимо использовать разбиение на возрастные группы, которое сделано в одном из столбцов датасета.
#
#   Слайд должен отвечать на вопрос: в какой из всех половозрастных категорий клиентов выгоднее привлекать новых клиентов при одинаковой стоимости привлечения клиента. Важно предварительно очистить данные.
#
#   На слайде должны быть:
#   - сводная таблица со средними прибылями в каждой категории;
#   - график (по желанию);
#   - вывод — клиентов какой категории привлекать выгоднее.
#
# 3. (black, баллы: 1.6) Теперь разрешается разбивать клиентов на произвольные группы по возрасту. Значит, могут возникнуть новые половозрастные категории.
#
#   Слайд должен отвечать на вопрос: в какой новой категории прибыль выше, чем во всех старых категориях из предыдущих слайдов.
#
#   Требования к слайду:
#   - вывод сделан;
#   - вывод обоснован графиком/таблицей;
#   - таблица/график понятны;
#   - таблица/график корректно посчитаны по датасету кейса.

# %% [markdown]
# **Решение этого задания нужно загрузить отдельным файлом .pptx, в котором:**
#
# **Cиний уровень — один слайд**
#
# **Красный уровень — ещё один слайд, всего два слайда**
#
# **Чёрный уровень — ещё один слайд, всего три слайда**

# %% [markdown]
# # Задача 6. Выбери подходящий график для представления данных

# %% [markdown]
# Ниже будет несколько ситуаций, для каждой из которых нужно подобрать подходящий график. Потребуется:
# - заголовок;
# - подписи осей (если есть оси);
# - единицы измерения;
# - легенда или подписи прямо внутри элементов графика;
# - пример того, как мог бы выглядеть график. Нарисуй от руки. Данных в задаче нет, поэтому как график будет выглядеть на самом деле, неизвестно. Нужен лишь пример, каким график мог бы быть. Вместо рисования от руки можно воспользоваться средствами matplotlib на выдуманных данных.
#
# Нарисуйте пример графика, показывающего:
#
# 1. (red, баллы: 0.5) Доли рынка производителей смартфонов в 2026-м году.
#
# 2. (red, баллы: 0.5) Изменение долей рынка производителей смартфонов с 2026 по 2028 год.
#
# 3. (red, баллы: 0.5) Динамику прибыли интернет-магазина в январе.
#
# 4. (black, баллы: 1) Одинаковость прибыли интернет-магазина в расчете на человека среди мужчин и женщин.
#
# 5. (black, баллы: 1) Как с ростом числа филиалов в торговой сети меняется набор городов присутствия этой сети.

# %% [markdown]
# **Решение**

# %% [markdown]
# **{Нарисуй все графики от руки и прикрепи картинку сюда}**

# %% [markdown]
# # Задача 7. Проверь, как меняется график при изменении данных, и увидим ли мы это на графике

# %% [markdown]
# В каждом пункте дан произвольный barchart. Ответ должен подходить для любого barchart.
#
# 1. (red, баллы: 0.6) Как изменится barchart, если значения вместо тысяч рублей перевести в рубли?
#
# 2. (red, баллы: 0.6) Как изменится barchart относительных частот, если в каждой категории станет в два раза больше наблюдений?
#
# 3. (black, баллы: 2) Как изменится barchart относительных частот, если в одной категории станет в два раза больше наблюдений, а в остальных останется столько же?
#
# 4. (black, баллы: 2) Как изменится barchart относительных частот, построенный на основе 500 наблюдений, если добавится одно очень большое наблюдение (выброс)?

# %% [markdown]
# **Решение**

# %% [markdown]
# # Задача 8. Приблизительно найди среднее, медиану по barchart

# %% [markdown]
# (black, баллы: 1.5) Ниже представлен график результатов дополнительных вступительных испытаний по математике в МГУ в 2023 году.
#
# Найди приблизительно или точно средний и медианный результат абитуриентов. Проинтерпретируй медианный результат.

# %% [markdown]
#   ![New_graph.png](data:image/png;base64,...)

# %% [markdown]
# Ответы на незаданные вопросы:
# - Нет, на графике нет ошибок.
# - Да, баллы 2 и 27 настоящие.
# - Да, промежуточных значений не было. Например, никто не набрал ровно 20 баллов.

# %% [markdown]
# Источник: https://pk.cs.msu.ru/node/306

# %% [markdown]
# **Решение**

# %% [markdown]
# # Задача 9. По заданному графику «из интернета» прокомментируй, почему этот график может вводить в заблуждение читателя и в какое именно заблуждение

# %% [markdown]
# Для каждого из графиков ниже объясни, к каким неверным выводам он может подтолкнуть читателя.

# %% [markdown]
# ## 1. (black, баллы: 0.3)
#
#  ![SHOULD BRITAIN LEAVE?.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Решение**

# %% [markdown]
# ## 2. (black, баллы: 0.3)
#
# ![Задание3№9.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Решение**

# %% [markdown]
# ## 3. (black, баллы: 0.3)
#
# ![BarChart.png](data:image/png;base64,...)

# %% [markdown]
# **Решение**
